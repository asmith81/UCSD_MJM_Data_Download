# %%
import os
import tensorflow as tf

from doctr.models import ocr_predictor

# %%
ocr_model = ocr_predictor(pretrained= False)
# Out:
# ...
#   0%|          | 0/55334536 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 ocr_model = ocr_predictor(pretrained= False)
#
# File d:\UCSD_MJM_Capstone\.venv\Lib\site-packages\doctr\models\zoo.py:112, in ocr_predictor(det_arch, reco_arch, pretrained, pretrained_backbone, assume_straight_pages, preserve_aspect_ratio, symmetric_pad, export_as_straight_boxes, detect_orientation, straighten_pages, detect_language, **kwargs)
#      63 def ocr_predictor(
#      64     det_arch: Any = "fast_base",
#      65     reco_arch: Any = "crnn_vgg16_bn",
#    (...)
#      75     **kwargs: Any,
#      76 ) -> OCRPredictor:
#      77     """End-to-end OCR architecture using one model for localization, and another for text recognition.
#      78
#      79     >>> import numpy as np
#    (...)
#     110         OCR predictor
#     111     """
# ...
